# %% [markdown]
# # Sentiment Analysis on Amazon reviews

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.pandas.set_option('display.max_columns',None)

# %%
df = pd.read_csv('C:\\Users\\Varadharajan Palani\\Downloads\\archive\\1429_1.csv')
df.head(3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# 0  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 1  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 2  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
#
#                reviews.date     reviews.dateAdded  \
# 0  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 1  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 2  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
#
#                                     reviews.dateSeen reviews.didPurchase  \
# 0  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z                 NaN
# 1  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z                 NaN
# 2  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z                 NaN
#
#   reviews.doRecommend  reviews.id  reviews.numHelpful  reviews.rating  \
# 0                True         NaN                 0.0             5.0
# 1                True         NaN                 0.0             5.0
# 2                True         NaN                 0.0             5.0
#
#                                   reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5620406/review...
# 1  http://reviews.bestbuy.com/3545/5620406/review...
# 2  http://reviews.bestbuy.com/3545/5620406/review...
#
#                                         reviews.text  \
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
#
#                              reviews.title  reviews.userCity  \
# 0                                   Kindle               NaN
# 1                                very fast               NaN
# 2  Beginner tablet for our 9 year old son.               NaN
#
#    reviews.userProvince reviews.username
# 0                   NaN          Adapter
# 1                   NaN           truman
# 2                   NaN            DaveZ

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.shape
# Out:
# (34660, 21)

# %%
df.describe()
# Out:
#         reviews.id  reviews.numHelpful  reviews.rating  reviews.userCity  \
# count          1.0        34131.000000    34627.000000               0.0
# mean   111372787.0            0.630248        4.584573               NaN
# std            NaN           13.215775        0.735653               NaN
# min    111372787.0            0.000000        1.000000               NaN
# 25%    111372787.0            0.000000        4.000000               NaN
# 50%    111372787.0            0.000000        5.000000               NaN
# 75%    111372787.0            0.000000        5.000000               NaN
# max    111372787.0          814.000000        5.000000               NaN
#
#        reviews.userProvince
# count                   0.0
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34660 entries, 0 to 34659
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    34660 non-null  object
#  1   name                  27900 non-null  object
#  2   asins                 34658 non-null  object
#  3   brand                 34660 non-null  object
#  4   categories            34660 non-null  object
#  5   keys                  34660 non-null  object
#  6   manufacturer          34660 non-null  object
#  7   reviews.date          34621 non-null  object
#  8   reviews.dateAdded     24039 non-null  object
#  9   reviews.dateSeen      34660 non-null  object
#  10  reviews.didPurchase   1 non-null      object
#  11  reviews.doRecommend   34066 non-null  object
#  12  reviews.id            1 non-null      float64
#  13  reviews.numHelpful    34131 non-null  float64
#  14  reviews.rating        34627 non-null  float64
#  15  reviews.sourceURLs    34660 non-null  object
#  16  reviews.text          34659 non-null  object
#  17  reviews.title         34655 non-null  object
#  18  reviews.userCity      0 non-null      float64
#  19  reviews.userProvince  0 non-null      float64
#  20  reviews.username      34658 non-null  object
# dtypes: float64(5), object(16)
# memory usage: 5.6+ MB

# %%
df['reviews.rating'].value_counts()
# Out:
# 5.0    23775
# 4.0     8541
# 3.0     1499
# 1.0      410
# 2.0      402
# Name: reviews.rating, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='reviews.rating', data=df, palette='Set1')
plt.xlabel('Rating')
plt.show()

# %% [markdown]
# data = df.copy()
# feature_col = data[['reviews.numHelpful','id','name','asins']]
# for feature in feature_col:
#     plt.figure(figsize=(20,20))
#     sns.countplot(x=feature, data=df, palette='Set1')
#     plt.xlabel(feature)
#     plt.show()

# %%
data = df.copy()
data.hist(figsize=(20,15))
plt.show()

# %%
data =df.copy()
data['reviews.numHelpful'].value_counts()
# Out:
# 0.0      30820
# 1.0       2049
# 2.0        562
# 3.0        190
# 4.0        122
#          ...
# 744.0        1
# 740.0        1
# 109.0        1
# 139.0        1
# 62.0         1
# Name: reviews.numHelpful, Length: 97, dtype: int64

# %%
df['reviews.didPurchase'].value_counts()
# Out:
# True    1
# Name: reviews.didPurchase, dtype: int64

# %%
df['reviews.doRecommend'].value_counts()
# Out:
# True     32682
# False     1384
# Name: reviews.doRecommend, dtype: int64

# %%
df['reviews.id'].value_counts()
# Out:
# 111372787.0    1
# Name: reviews.id, dtype: int64

# %%
df['reviews.userCity'].value_counts()
# Out:
# Series([], Name: reviews.userCity, dtype: int64)

# %%
df['reviews.userProvince'].value_counts()
# Out:
# Series([], Name: reviews.userProvince, dtype: int64)

# %%
df['brand'].value_counts()
# Out:
# Amazon                          28701
# Amazon Fire Tv                   5056
# Amazon Echo                       636
# Amazon Fire                       256
# Amazon Digital Services Inc.       10
# Amazon Coco T                       1
# Name: brand, dtype: int64

# %%
df['reviews.username'].value_counts()
# Out:
# Mike            138
# Chris            93
# John             85
# Dave             70
# Bill             58
#                ...
# poorteacher       1
# superdave213      1
# zgibbs            1
# Jayman            1
# KYamLegend        1
# Name: reviews.username, Length: 26789, dtype: int64

# %% [markdown]
# ### asins with rate

# %%
asin1 = df[df['asins'] == 'B01AHB9CN2']
df.groupby('asins').agg('count')
# Out:
#                           id   name  brand  categories   keys  manufacturer  \
# asins
# B002Y27P3M                19     19     19          19     19            19
# B002Y27P6Y                10      0     10          10     10            10
# B005PB2T0S                 5      5      5           5      5             5
# B005PB2T2Q                 6      6      6           6      6             6
# B006GWO5NE                 8      0      8           8      8             8
# B006GWO5WK                13      0     13          13     13            13
# B0083Q04TA                 4      4      4           4      4             4
# B00BFJAHF8                 1      0      1           1      1             1
# B00DU15MU4                 6      6      6           6      6             6
# B00IOY8XWQ               580    580    580         580    580           580
# B00IOYAM4I                51     51     51          51     51            51
# B00L9EPT8O,B01E6AO69U   6619   5948   6619        6619   6619          6619
# B00LO29KXQ                 3      3      3           3      3             3
# B00LW9XOJM                13      0     13          13     13            13
# B00OQVZDJM              3176   3176   3176        3176   3176          3176
# B00QFQRELG                73      0     73          73     73            73
# B00QJDU3KY                19     19     19          19     19            19
# B00QL1ZN3G                15      0     15          15     15            15
# B00REQKWGA                 6      6      6           6      6             6
# B00TSUGXKE               372    372    372         372    372           372
# B00U3FPN4U              5056      0   5056        5056   5056          5056
# B00UH4D8G2                 8      8      8           8      8             8
# B00VINDBJK                67     67     67          67     67            67
# B00X4WHP5E                 7      0      7           7      7             7
# B00ZV9PXP2               212    212    212         212    212           212
# B0189XYY0Q               256      0    256         256    256           256
# B018SZT3BK               270    270    270         270    270           270
# B018T075DC                 7      7      7           7      7             7
# B018Y225IA              1038   1038   1038        1038   1038          1038
# B018Y229OU             10966  10966  10966       10966  10966         10966
# B018Y22BI4                10     10     10          10     10            10
# B018Y22C2Y                 6      6      6           6      6             6
# B018Y23MNM              1685   1685   1685        1685   1685          1685
# B018Y23P7K                 1      0      1           1      1             1
# B01AHB9C1E                14     14     14          14     14            14
# B01AHB9CN2              2814   2814   2814        2814   2814          2814
# B01AHB9CYG               158    158    158         158    158           158
# B01BFIBRIE                30     30     30          30     30            30
# B01BH83OOM               636      0    636         636    636           636
# B01J2G4VBG               402    402    402         402    402           402
# B01J4ORNHU                16     16     16          16     16            16
#
#                        reviews.date  reviews.dateAdded  reviews.dateSeen  \
# asins
# B002Y27P3M                       11                  0                19
# B002Y27P6Y                        9                  0                10
# B005PB2T0S                        4                  0                 5
# B005PB2T2Q                        4                  0                 6
# B006GWO5NE                        6                  0                 8
# B006GWO5WK                       13                  0                13
# B0083Q04TA                        4                  0                 4
# B00BFJAHF8                        0                  0                 1
# B00DU15MU4                        4                  0                 6
# B00IOY8XWQ                      580                  0               580
# B00IOYAM4I                       51                 51                51
# B00L9EPT8O,B01E6AO69U          6618                  0              6619
# B00LO29KXQ                        0                  0                 3
# B00LW9XOJM                       13                  0                13
# B00OQVZDJM                     3176               3176              3176
# B00QFQRELG                       71                  0                73
# B00QJDU3KY                        9                  0                19
# B00QL1ZN3G                       14                  0                15
# B00REQKWGA                        6                  6                 6
# B00TSUGXKE                      372                  0               372
# B00U3FPN4U                     5054               5056              5056
# B00UH4D8G2                        8                  0                 8
# B00VINDBJK                       67                 67                67
# B00X4WHP5E                        7                  0                 7
# B00ZV9PXP2                      212                  0               212
# B0189XYY0Q                      256                  0               256
# B018SZT3BK                      270                  0               270
# B018T075DC                        7                  7                 7
# B018Y225IA                     1038                  0              1038
# B018Y229OU                    10966              10966             10966
# B018Y22BI4                       10                  0                10
# B018Y22C2Y                        6                  6                 6
# B018Y23MNM                     1685               1685              1685
# B018Y23P7K                        1                  1                 1
# B01AHB9C1E                       14                 14                14
# B01AHB9CN2                     2814               2814              2814
# B01AHB9CYG                      158                158               158
# B01BFIBRIE                       30                 30                30
# B01BH83OOM                      634                  0               636
# B01J2G4VBG                      402                  0               402
# B01J4ORNHU                       15                  0                16
#
#                        reviews.didPurchase  reviews.doRecommend  reviews.id  \
# asins
# B002Y27P3M                               0                    0           0
# B002Y27P6Y                               0                    0           0
# B005PB2T0S                               0                    0           0
# B005PB2T2Q                               0                    0           0
# B006GWO5NE                               0                    0           0
# B006GWO5WK                               0                    0           0
# B0083Q04TA                               0                    0           0
# B00BFJAHF8                               0                    0           0
# B00DU15MU4                               0                    0           0
# B00IOY8XWQ                               0                  580           0
# B00IOYAM4I                               0                   51           0
# B00L9EPT8O,B01E6AO69U                    0                 6608           0
# B00LO29KXQ                               0                    0           0
# B00LW9XOJM                               0                    0           0
# B00OQVZDJM                               1                 3176           1
# B00QFQRELG                               0                   54           0
# B00QJDU3KY                               0                    0           0
# B00QL1ZN3G                               0                    0           0
# B00REQKWGA                               0                    6           0
# B00TSUGXKE                               0                  372           0
# B00U3FPN4U                               0                 5052           0
# B00UH4D8G2                               0                    0           0
# B00VINDBJK                               0                   67           0
# B00X4WHP5E                               0                    2           0
# B00ZV9PXP2                               0                  212           0
# B0189XYY0Q                               0                  255           0
# B018SZT3BK                               0                  269           0
# B018T075DC                               0                    7           0
# B018Y225IA                               0                 1038           0
# B018Y229OU                               0                10966           0
# B018Y22BI4                               0                   10           0
# B018Y22C2Y                               0                    6           0
# B018Y23MNM                               0                 1685           0
# B018Y23P7K                               0                    1           0
# B01AHB9C1E                               0                   14           0
# B01AHB9CN2                               0                 2814           0
# B01AHB9CYG                               0                  158           0
# B01BFIBRIE                               0                   30           0
# B01BH83OOM                               0                  633           0
# B01J2G4VBG                               0                    0           0
# B01J4ORNHU                               0                    0           0
#
#                        reviews.numHelpful  reviews.rating  reviews.sourceURLs  \
# asins
# B002Y27P3M                              0               0                  19
# B002Y27P6Y                              4              10                  10
# B005PB2T0S                              5               5                   5
# B005PB2T2Q                              6               6                   6
# B006GWO5NE                              0               8                   8
# B006GWO5WK                              0              13                  13
# B0083Q04TA                              0               0                   4
# B00BFJAHF8                              0               0                   1
# B00DU15MU4                              0               1                   6
# B00IOY8XWQ                            580             580                 580
# B00IOYAM4I                             51              51                  51
# B00L9EPT8O,B01E6AO69U                6608            6619                6619
# B00LO29KXQ                              3               3                   3
# B00LW9XOJM                              2              13                  13
# B00OQVZDJM                           3176            3176                3176
# B00QFQRELG                             66              73                  73
# B00QJDU3KY                              5              15                  19
# B00QL1ZN3G                              8              15                  15
# B00REQKWGA                              6               6                   6
# B00TSUGXKE                            372             372                 372
# B00U3FPN4U                           5056            5056                5056
# B00UH4D8G2                              7               8                   8
# B00VINDBJK                             67              67                  67
# B00X4WHP5E                              0               7                   7
# B00ZV9PXP2                            212             212                 212
# B0189XYY0Q                            256             256                 256
# B018SZT3BK                            269             270                 270
# B018T075DC                              7               7                   7
# B018Y225IA                           1038            1038                1038
# B018Y229OU                          10966           10966               10966
# B018Y22BI4                             10              10                  10
# B018Y22C2Y                              6               6                   6
# B018Y23MNM                           1685            1685                1685
# B018Y23P7K                              1               1                   1
# B01AHB9C1E                             14              14                  14
# B01AHB9CN2                           2814            2814                2814
# B01AHB9CYG                            158             158                 158
# B01BFIBRIE                             30              30                  30
# B01BH83OOM                            636             636                 636
# B01J2G4VBG                              3             402                 402
# B01J4ORNHU                              4              16                  16
#
#                        reviews.text  reviews.title  reviews.userCity  \
# asins
# B002Y27P3M                       19             19                 0
# B002Y27P6Y                       10             10                 0
# B005PB2T0S                        5              5                 0
# B005PB2T2Q                        6              6                 0
# B006GWO5NE                        8              8                 0
# B006GWO5WK                       13             13                 0
# B0083Q04TA                        4              4                 0
# B00BFJAHF8                        1              1                 0
# B00DU15MU4                        6              6                 0
# B00IOY8XWQ                      580            580                 0
# B00IOYAM4I                       51             51                 0
# B00L9EPT8O,B01E6AO69U          6619           6617                 0
# B00LO29KXQ                        3              3                 0
# B00LW9XOJM                       13             13                 0
# B00OQVZDJM                     3176           3176                 0
# B00QFQRELG                       73             73                 0
# B00QJDU3KY                       19             19                 0
# B00QL1ZN3G                       15             15                 0
# B00REQKWGA                        6              6                 0
# B00TSUGXKE                      372            372                 0
# B00U3FPN4U                     5056           5056                 0
# B00UH4D8G2                        8              8                 0
# B00VINDBJK                       67             67                 0
# B00X4WHP5E                        7              6                 0
# B00ZV9PXP2                      212            212                 0
# B0189XYY0Q                      256            255                 0
# B018SZT3BK                      270            270                 0
# B018T075DC                        7              7                 0
# B018Y225IA                     1038           1038                 0
# B018Y229OU                    10966          10966                 0
# B018Y22BI4                       10             10                 0
# B018Y22C2Y                        6              6                 0
# B018Y23MNM                     1685           1685                 0
# B018Y23P7K                        1              1                 0
# B01AHB9C1E                       14             14                 0
# B01AHB9CN2                     2814           2814                 0
# B01AHB9CYG                      158            158                 0
# B01BFIBRIE                       30             30                 0
# B01BH83OOM                      636            636                 0
# B01J2G4VBG                      401            401                 0
# B01J4ORNHU                       16             16                 0
#
#                        reviews.userProvince  reviews.username
# asins
# B002Y27P3M                                0                19
# B002Y27P6Y                                0                10
# B005PB2T0S                                0                 5
# B005PB2T2Q                                0                 6
# B006GWO5NE                                0                 8
# B006GWO5WK                                0                13
# B0083Q04TA                                0                 4
# B00BFJAHF8                                0                 1
# B00DU15MU4                                0                 6
# B00IOY8XWQ                                0               580
# B00IOYAM4I                                0                51
# B00L9EPT8O,B01E6AO69U                     0              6618
# B00LO29KXQ                                0                 3
# B00LW9XOJM                                0                13
# B00OQVZDJM                                0              3176
# B00QFQRELG                                0                73
# B00QJDU3KY                                0                19
# B00QL1ZN3G                                0                15
# B00REQKWGA                                0                 6
# B00TSUGXKE                                0               372
# B00U3FPN4U                                0              5056
# B00UH4D8G2                                0                 8
# B00VINDBJK                                0                67
# B00X4WHP5E                                0                 7
# B00ZV9PXP2                                0               212
# B0189XYY0Q                                0               256
# B018SZT3BK                                0               270
# B018T075DC                                0                 7
# B018Y225IA                                0              1038
# B018Y229OU                                0             10965
# B018Y22BI4                                0                10
# B018Y22C2Y                                0                 6
# B018Y23MNM                                0              1685
# B018Y23P7K                                0                 1
# B01AHB9C1E                                0                14
# B01AHB9CN2                                0              2814
# B01AHB9CYG                                0               158
# B01BFIBRIE                                0                30
# B01BH83OOM                                0               636
# B01J2G4VBG                                0               402
# B01J4ORNHU                                0                16

# %%
df.groupby('reviews.rating').agg('count')
# Out:
#                    id   name  asins  brand  categories   keys  manufacturer  \
# reviews.rating
# 1.0               410    326    410    410         410    410           410
# 2.0               402    339    402    402         402    402           402
# 3.0              1499   1289   1499   1499        1499   1499          1499
# 4.0              8541   7220   8540   8541        8541   8541          8541
# 5.0             23775  18694  23774  23775       23775  23775         23775
#
#                 reviews.date  reviews.dateAdded  reviews.dateSeen  \
# reviews.rating
# 1.0                      410                269               410
# 2.0                      402                280               402
# 3.0                     1499               1081              1499
# 4.0                     8531               6191              8541
# 5.0                    23756              16218             23775
#
#                 reviews.didPurchase  reviews.doRecommend  reviews.id  \
# reviews.rating
# 1.0                               0                  356           0
# 2.0                               0                  382           0
# 3.0                               0                 1470           0
# 4.0                               0                 8469           0
# 5.0                               1                23389           1
#
#                 reviews.numHelpful  reviews.sourceURLs  reviews.text  \
# reviews.rating
# 1.0                            375                 410           410
# 2.0                            388                 402           402
# 3.0                           1475                1499          1499
# 4.0                           8480                8541          8541
# 5.0                          23413               23775         23774
#
#                 reviews.title  reviews.userCity  reviews.userProvince  \
# reviews.rating
# 1.0                       410                 0                     0
# 2.0                       402                 0                     0
# 3.0                      1499                 0                     0
# 4.0                      8541                 0                     0
# 5.0                     23770                 0                     0
#
#                 reviews.username
# reviews.rating
# 1.0                          410
# 2.0                          402
# 3.0                         1499
# 4.0                         8541
# 5.0                        23773

# %% [markdown]
# ### Data Preprocessing

# %%
data = df.copy()
data_new = data.dropna(subset=['reviews.rating'])
len(data_new)
# Out:
# 34627

# %%
corr_matrix = data.corr() #correlation between columns
corr_matrix
# Out:
#                       reviews.id  reviews.numHelpful  reviews.rating  \
# reviews.id                   NaN                 NaN             NaN
# reviews.numHelpful           NaN            1.000000       -0.042395
# reviews.rating               NaN           -0.042395        1.000000
# reviews.userCity             NaN                 NaN             NaN
# reviews.userProvince         NaN                 NaN             NaN
#
#                       reviews.userCity  reviews.userProvince
# reviews.id                         NaN                   NaN
# reviews.numHelpful                 NaN                   NaN
# reviews.rating                     NaN                   NaN
# reviews.userCity                   NaN                   NaN
# reviews.userProvince               NaN                   NaN

# %%
for feature in data.columns:
    print('Total unique value in {} is {}'.format(feature, len(data[feature].unique())))
# Out:
# Total unique value in id is 42
# Total unique value in name is 49
# Total unique value in asins is 42
# Total unique value in brand is 6
# Total unique value in categories is 41
# Total unique value in keys is 42
# Total unique value in manufacturer is 2
# Total unique value in reviews.date is 1079
# Total unique value in reviews.dateAdded is 1942
# Total unique value in reviews.dateSeen is 3911
# Total unique value in reviews.didPurchase is 2
# Total unique value in reviews.doRecommend is 3
# Total unique value in reviews.id is 2
# Total unique value in reviews.numHelpful is 98
# Total unique value in reviews.rating is 6
# Total unique value in reviews.sourceURLs is 11929
# Total unique value in reviews.text is 34660
# Total unique value in reviews.title is 19768
# Total unique value in reviews.userCity is 1
# Total unique value in reviews.userProvince is 1
# Total unique value in reviews.username is 26790

# %%
data.head(1)
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# 0  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
#
#                reviews.date     reviews.dateAdded  \
# 0  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
#
#                                     reviews.dateSeen reviews.didPurchase  \
# 0  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z                 NaN
#
#   reviews.doRecommend  reviews.id  reviews.numHelpful  reviews.rating  \
# 0                True         NaN                 0.0             5.0
#
#                                   reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5620406/review...
#
#                                         reviews.text reviews.title  \
# 0  This product so far has not disappointed. My c...        Kindle
#
#    reviews.userCity  reviews.userProvince reviews.username
# 0               NaN                   NaN          Adapter

# %%
df1 = data[['brand','manufacturer','reviews.doRecommend','reviews.numHelpful','reviews.rating','reviews.text']]

# %%
df1.head(3)
# Out:
#     brand manufacturer reviews.doRecommend  reviews.numHelpful  \
# 0  Amazon       Amazon                True                 0.0
# 1  Amazon       Amazon                True                 0.0
# 2  Amazon       Amazon                True                 0.0
#
#    reviews.rating                                       reviews.text
# 0             5.0  This product so far has not disappointed. My c...
# 1             5.0  great for beginner or experienced person. Boug...
# 2             5.0  Inexpensive tablet for him to use and learn on...

# %%
d = pd.read_csv('C:\\Users\\Varadharajan Palani\\Downloads\\archive\\Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv')
d.head(3)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 2  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# 0   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 1   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 2   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys  manufacturer  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
# 1  amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
# 2  amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
#
#   manufacturerNumber              reviews.date      reviews.dateSeen  \
# 0          HL-002619  2017-03-02T00:00:00.000Z  2017-08-28T00:00:00Z
# 1          HL-002619  2016-08-31T00:00:00.000Z  2017-08-28T00:00:00Z
# 2          HL-002619  2016-12-06T00:00:00.000Z  2017-08-28T00:00:00Z
#
#   reviews.didPurchase reviews.doRecommend  reviews.id  reviews.numHelpful  \
# 0                 NaN                 NaN         NaN                 NaN
# 1                 NaN                 NaN         NaN                 NaN
# 2                 NaN                 NaN         NaN                 NaN
#
#    reviews.rating                                 reviews.sourceURLs  \
# 0               3  https://www.amazon.com/product-reviews/B00QWO9...
# 1               4  https://www.amazon.com/product-reviews/B00QWO9...
# 2               5  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                         reviews.text  \
# 0  I order 3 of them and one of the item is bad q...
# 1  Bulk is always the less expensive way to go fo...
# 2  Well they are not Duracell but for the price i...
#
#                                        reviews.title  reviews.username  \
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
# 2  ... are not Duracell but for the price i am ha...  BySharon Lambert
#
#                                           sourceURLs
# 0  https://www.barcodable.com/upc/841710106442,ht...
# 1  https://www.barcodable.com/upc/841710106442,ht...
# 2  https://www.barcodable.com/upc/841710106442,ht...

# %%
df2 = d[['brand','manufacturer','reviews.doRecommend','reviews.numHelpful','reviews.rating','reviews.text']]

# %%
df2.head()
# Out:
#           brand  manufacturer reviews.doRecommend  reviews.numHelpful  \
# 0  Amazonbasics  AmazonBasics                 NaN                 NaN
# 1  Amazonbasics  AmazonBasics                 NaN                 NaN
# 2  Amazonbasics  AmazonBasics                 NaN                 NaN
# 3  Amazonbasics  AmazonBasics                 NaN                 NaN
# 4  Amazonbasics  AmazonBasics                 NaN                 NaN
#
#    reviews.rating                                       reviews.text
# 0               3  I order 3 of them and one of the item is bad q...
# 1               4  Bulk is always the less expensive way to go fo...
# 2               5  Well they are not Duracell but for the price i...
# 3               5  Seem to work as well as name brand batteries a...
# 4               5  These batteries are very long lasting the pric...

# %%
df2.shape
# Out:
# (28332, 6)

# %%
 df2['reviews.numHelpful'].value_counts()
# Out:
# 0.0      14878
# 1.0        589
# 2.0        256
# 3.0         82
# 4.0         58
#          ...
# 47.0         1
# 621.0        1
# 55.0         1
# 45.0         1
# 220.0        1
# Name: reviews.numHelpful, Length: 61, dtype: int64

# %%
df2['brand'].value_counts()
# Out:
# Amazon          16153
# Amazonbasics    12169
# AmazonBasics       10
# Name: brand, dtype: int64

# %%
df2['manufacturer'].value_counts()
# Out:
# Amazon                     16130
# AmazonBasics               12179
# Amazon Digital Services       18
# Amazon.com                     5
# Name: manufacturer, dtype: int64

# %%
df2['reviews.doRecommend'].value_counts()
# Out:
# True     15353
# False      733
# Name: reviews.doRecommend, dtype: int64

# %%
df2.isnull().sum()
# Out:
# brand                      0
# manufacturer               0
# reviews.doRecommend    12246
# reviews.numHelpful     12217
# reviews.rating             0
# reviews.text               0
# dtype: int64

# %%
df2 = df2.dropna()

# %%
df2.isnull().sum()
# Out:
# brand                  0
# manufacturer           0
# reviews.doRecommend    0
# reviews.numHelpful     0
# reviews.rating         0
# reviews.text           0
# dtype: int64

# %%
corr_mat = df2.corr()
corr_mat
# Out:
#                     reviews.numHelpful  reviews.rating
# reviews.numHelpful            1.000000       -0.022648
# reviews.rating               -0.022648        1.000000

# %%
dd = pd.read_csv('C:\\Users\\Varadharajan Palani\\Downloads\\archive\\Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv')
dd.head(3)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# 0  Computers,Electronics Features,Tablets,Electro...       Electronics
# 1  Computers,Electronics Features,Tablets,Electro...       Electronics
# 2  Computers,Electronics Features,Tablets,Electro...       Electronics
#
#                                            imageURLs  \
# 0  https://pisces.bbystatic.com/image2/BestBuy_US...
# 1  https://pisces.bbystatic.com/image2/BestBuy_US...
# 2  https://pisces.bbystatic.com/image2/BestBuy_US...
#
#                                                 keys manufacturer  \
# 0  allnewkindleereaderblack6glarefreetouchscreend...       Amazon
# 1  allnewkindleereaderblack6glarefreetouchscreend...       Amazon
# 2  allnewkindleereaderblack6glarefreetouchscreend...       Amazon
#
#   manufacturerNumber              reviews.date reviews.dateAdded  \
# 0         B00ZV9PXP2  2017-09-03T00:00:00.000Z               NaN
# 1         B00ZV9PXP2  2017-06-06T00:00:00.000Z               NaN
# 2         B00ZV9PXP2  2018-04-20T00:00:00.000Z               NaN
#
#                                     reviews.dateSeen  reviews.doRecommend  \
# 0  2018-05-27T00:00:00Z,2017-09-18T00:00:00Z,2017...                False
# 1  2018-05-27T00:00:00Z,2017-07-07T00:00:00Z,2017...                 True
# 2                               2018-05-27T00:00:00Z                 True
#
#    reviews.id  reviews.numHelpful  reviews.rating  \
# 0         NaN                   0               3
# 1         NaN                   0               5
# 2         NaN                   0               4
#
#                                   reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5442403/review...
# 1  http://reviews.bestbuy.com/3545/5442403/review...
# 2  https://reviews.bestbuy.com/3545/5442403/revie...
#
#                                         reviews.text  \
# 0  I thought it would be as big as small paper bu...
# 1  This kindle is light and easy to use especiall...
# 2  Didnt know how much i'd use a kindle so went f...
#
#                                   reviews.title reviews.username  \
# 0                                     Too small           llyyue
# 1  Great light reader. Easy to use at the beach           Charmi
# 2                           Great for the price     johnnyjojojo
#
#                                           sourceURLs
# 0  https://www.newegg.com/Product/Product.aspx%25...
# 1  https://www.newegg.com/Product/Product.aspx%25...
# 2  https://www.newegg.com/Product/Product.aspx%25...

# %%
df3 = dd[['brand','manufacturer','reviews.doRecommend','reviews.numHelpful','reviews.rating','reviews.text']]

# %%
df3.head()
# Out:
#     brand manufacturer  reviews.doRecommend  reviews.numHelpful  \
# 0  Amazon       Amazon                False                   0
# 1  Amazon       Amazon                 True                   0
# 2  Amazon       Amazon                 True                   0
# 3  Amazon       Amazon                 True                   3
# 4  Amazon       Amazon                 True                   0
#
#    reviews.rating                                       reviews.text
# 0               3  I thought it would be as big as small paper bu...
# 1               5  This kindle is light and easy to use especiall...
# 2               4  Didnt know how much i'd use a kindle so went f...
# 3               5  I am 100 happy with my purchase. I caught it o...
# 4               5  Solid entry level Kindle. Great for kids. Gift...

# %%
#for feature in df3.columns:
   # print(df3[feature].value_counts())

# %%
df3.shape
# Out:
# (5000, 6)

# %%
df3.isnull().sum()
# Out:
# brand                  0
# manufacturer           0
# reviews.doRecommend    0
# reviews.numHelpful     0
# reviews.rating         0
# reviews.text           0
# dtype: int64

# %% [markdown]
# ### merging all dataset to a single dataset

# %%
frame = [df1 , df2]
dataset = pd.concat(frame)

# %%
dataset.shape
# Out:
# (50746, 6)

# %%
len(df1)+len(df2)
# Out:
# 50746

# %%
frame = [dataset, df3]
dataset = pd.concat(frame)

# %%
dataset.shape
# Out:
# (55746, 6)

# %%
dataset.head()
# Out:
#     brand manufacturer reviews.doRecommend  reviews.numHelpful  \
# 0  Amazon       Amazon                True                 0.0
# 1  Amazon       Amazon                True                 0.0
# 2  Amazon       Amazon                True                 0.0
# 3  Amazon       Amazon                True                 0.0
# 4  Amazon       Amazon                True                 0.0
#
#    reviews.rating                                       reviews.text
# 0             5.0  This product so far has not disappointed. My c...
# 1             5.0  great for beginner or experienced person. Boug...
# 2             5.0  Inexpensive tablet for him to use and learn on...
# 3             4.0  I've had my Fire HD 8 two weeks now and I love...
# 4             5.0  I bought this for my grand daughter when she c...

# %% [markdown]
# ### Adding sentiment columns to the datasets

# %%
temp_data = dataset.copy()

# %%
temp_data['sentiment'] = temp_data["reviews.rating"].apply(lambda score: "positive" if score > 3 else \
                                              ("negative" if score < 3 else "intermediate"))

# %%
temp_data.head()
# Out:
#     brand manufacturer reviews.doRecommend  reviews.numHelpful  \
# 0  Amazon       Amazon                True                 0.0
# 1  Amazon       Amazon                True                 0.0
# 2  Amazon       Amazon                True                 0.0
# 3  Amazon       Amazon                True                 0.0
# 4  Amazon       Amazon                True                 0.0
#
#    reviews.rating                                       reviews.text sentiment
# 0             5.0  This product so far has not disappointed. My c...  positive
# 1             5.0  great for beginner or experienced person. Boug...  positive
# 2             5.0  Inexpensive tablet for him to use and learn on...  positive
# 3             4.0  I've had my Fire HD 8 two weeks now and I love...  positive
# 4             5.0  I bought this for my grand daughter when she c...  positive

# %%
temp_data[temp_data['reviews.rating']==3]
# Out:
#        brand manufacturer reviews.doRecommend  reviews.numHelpful  \
# 222   Amazon       Amazon               False                 0.0
# 226   Amazon       Amazon               False                 0.0
# 298   Amazon       Amazon                True                 0.0
# 354   Amazon       Amazon                True                 0.0
# 371   Amazon       Amazon                True                 0.0
# ...      ...          ...                 ...                 ...
# 4807  Amazon       Amazon               False                 0.0
# 4842  Amazon       Amazon                True                 0.0
# 4880  Amazon       Amazon               False                 0.0
# 4945  Amazon       Amazon                True                 0.0
# 4975  Amazon       Amazon                True                 0.0
#
#       reviews.rating                                       reviews.text  \
# 222              3.0  I was hoping to use Google launcher with this ...
# 226              3.0  The tablet works fine. It is responsive with g...
# 298              3.0  Fine for reading, ...haven't used it for anyth...
# 354              3.0  Though I have got it for cheap price during bl...
# 371              3.0  This is a good product for video, surfing and ...
# ...              ...                                                ...
# 4807             3.0  meh. it works. i find it difficult to navigate...
# 4842             3.0  Decent little tablet if you are not a game pla...
# 4880             3.0  I bought this as a Christmas gift for my wife ...
# 4945             3.0  My daughter has had this tablet for almost 2 m...
# 4975             3.0  I wish it has some more of the apps from the p...
#
#          sentiment
# 222   intermediate
# 226   intermediate
# 298   intermediate
# 354   intermediate
# 371   intermediate
# ...            ...
# 4807  intermediate
# 4842  intermediate
# 4880  intermediate
# 4945  intermediate
# 4975  intermediate
#
# [2355 rows x 7 columns]

# %%
temp_data[temp_data['reviews.rating']==1]
# Out:
#        brand manufacturer reviews.doRecommend  reviews.numHelpful  \
# 126   Amazon       Amazon               False                 2.0
# 169   Amazon       Amazon               False                 2.0
# 241   Amazon       Amazon               False                 0.0
# 297   Amazon       Amazon               False                 0.0
# 310   Amazon       Amazon               False                 0.0
# ...      ...          ...                 ...                 ...
# 4761  Amazon       Amazon               False                 2.0
# 4795  Amazon       Amazon               False                 1.0
# 4823  Amazon       Amazon               False                 0.0
# 4865  Amazon       Amazon               False                 2.0
# 4953  Amazon       Amazon               False                 0.0
#
#       reviews.rating                                       reviews.text  \
# 126              1.0  i Bought this around black friday for $60 hopi...
# 169              1.0  I bought this tablet for my 4 year old daughte...
# 241              1.0  Didn't want to go to the sites amazon wanted m...
# 297              1.0  This Kindle is so overloaded with apps that I ...
# 310              1.0  I liked it at first except the browser is kind...
# ...              ...                                                ...
# 4761             1.0  The last 2 models of Kindle HDX 8 have been te...
# 4795             1.0  This is not an upgrade by any means! My three ...
# 4823             1.0  Bought this mostly as a backup.and to read a f...
# 4865             1.0  The last 2 models of Kindle HDX 8 have been te...
# 4953             1.0  Very cheap and was not impressed at all never ...
#
#      sentiment
# 126   negative
# 169   negative
# 241   negative
# 297   negative
# 310   negative
# ...        ...
# 4761  negative
# 4795  negative
# 4823  negative
# 4865  negative
# 4953  negative
#
# [679 rows x 7 columns]

# %%
temp_data[temp_data['reviews.rating']==2]
# Out:
#        brand manufacturer reviews.doRecommend  reviews.numHelpful  \
# 117   Amazon       Amazon                True                 0.0
# 281   Amazon       Amazon               False                 0.0
# 444   Amazon       Amazon               False                 0.0
# 446   Amazon       Amazon                True                 0.0
# 635   Amazon       Amazon               False                 0.0
# ...      ...          ...                 ...                 ...
# 4264  Amazon       Amazon               False                 0.0
# 4287  Amazon       Amazon               False                 0.0
# 4510  Amazon       Amazon               False                 0.0
# 4904  Amazon       Amazon               False                 0.0
# 4971  Amazon       Amazon               False                 0.0
#
#       reviews.rating                                       reviews.text  \
# 117              2.0  Didn't have some of the features I was looking...
# 281              2.0  Not a good product short battery life i can on...
# 444              2.0  If you shop on Amazon all the time, this will ...
# 446              2.0  fire tablet is very powerful for the size and ...
# 635              2.0  I have always gone to buy a kindle because I l...
# ...              ...                                                ...
# 4264             2.0  Hard to use, Lots of ads, and Randomly closes ...
# 4287             2.0  Loved my husbands 4th generation disappointed ...
# 4510             2.0  Loved my husbands 4th generation disappointed ...
# 4904             2.0  The battery is having more and more trouble ho...
# 4971             2.0  Hard to use, Lots of ads, and Randomly closes ...
#
#      sentiment
# 117   negative
# 281   negative
# 444   negative
# 446   negative
# 635   negative
# ...        ...
# 4264  negative
# 4287  negative
# 4510  negative
# 4904  negative
# 4971  negative
#
# [668 rows x 7 columns]

# %%
temp_data.shape
# Out:
# (55746, 7)

# %%
temp_data[temp_data['brand'] == temp_data['manufacturer']]
# Out:
#        brand manufacturer reviews.doRecommend  reviews.numHelpful  \
# 0     Amazon       Amazon                True                 0.0
# 1     Amazon       Amazon                True                 0.0
# 2     Amazon       Amazon                True                 0.0
# 3     Amazon       Amazon                True                 0.0
# 4     Amazon       Amazon                True                 0.0
# ...      ...          ...                 ...                 ...
# 4995  Amazon       Amazon                True                 0.0
# 4996  Amazon       Amazon                True                 1.0
# 4997  Amazon       Amazon                True                 8.0
# 4998  Amazon       Amazon                True                 0.0
# 4999  Amazon       Amazon                True                 0.0
#
#       reviews.rating                                       reviews.text  \
# 0                5.0  This product so far has not disappointed. My c...
# 1                5.0  great for beginner or experienced person. Boug...
# 2                5.0  Inexpensive tablet for him to use and learn on...
# 3                4.0  I've had my Fire HD 8 two weeks now and I love...
# 4                5.0  I bought this for my grand daughter when she c...
# ...              ...                                                ...
# 4995             5.0  This is a great tablet for the price. Amazon i...
# 4996             5.0  This tablet is the perfect size and so easy to...
# 4997             4.0  Purchased this for my son. Has room to upgrade...
# 4998             5.0  I had some thoughts about getting this for a 5...
# 4999             5.0  this is a steal, have 8 gb model as well.This ...
#
#      sentiment
# 0     positive
# 1     positive
# 2     positive
# 3     positive
# 4     positive
# ...        ...
# 4995  positive
# 4996  positive
# 4997  positive
# 4998  positive
# 4999  positive
#
# [49766 rows x 7 columns]

# %%
len(temp_data[temp_data['brand'] == temp_data['manufacturer']])/len(temp_data)
# Out:
# 0.8927277293438094

# %%
temp_data = temp_data[temp_data['brand'] == temp_data['manufacturer']]

# %%
temp_data.shape
# Out:
# (49766, 7)

# %%
temp_data = temp_data.drop(['manufacturer'] , axis = 'columns')

# %%
temp_data.head()
# Out:
#     brand reviews.doRecommend  reviews.numHelpful  reviews.rating  \
# 0  Amazon                True                 0.0             5.0
# 1  Amazon                True                 0.0             5.0
# 2  Amazon                True                 0.0             5.0
# 3  Amazon                True                 0.0             4.0
# 4  Amazon                True                 0.0             5.0
#
#                                         reviews.text sentiment
# 0  This product so far has not disappointed. My c...  positive
# 1  great for beginner or experienced person. Boug...  positive
# 2  Inexpensive tablet for him to use and learn on...  positive
# 3  I've had my Fire HD 8 two weeks now and I love...  positive
# 4  I bought this for my grand daughter when she c...  positive

# %%
temp_data['DoRecommend'] = temp_data["reviews.doRecommend"].apply(lambda x: 1 if True else 0)

# %%
temp_data[temp_data['DoRecommend'] == 1]
# Out:
#        brand reviews.doRecommend  reviews.numHelpful  reviews.rating  \
# 0     Amazon                True                 0.0             5.0
# 1     Amazon                True                 0.0             5.0
# 2     Amazon                True                 0.0             5.0
# 3     Amazon                True                 0.0             4.0
# 4     Amazon                True                 0.0             5.0
# ...      ...                 ...                 ...             ...
# 4995  Amazon                True                 0.0             5.0
# 4996  Amazon                True                 1.0             5.0
# 4997  Amazon                True                 8.0             4.0
# 4998  Amazon                True                 0.0             5.0
# 4999  Amazon                True                 0.0             5.0
#
#                                            reviews.text sentiment  DoRecommend
# 0     This product so far has not disappointed. My c...  positive            1
# 1     great for beginner or experienced person. Boug...  positive            1
# 2     Inexpensive tablet for him to use and learn on...  positive            1
# 3     I've had my Fire HD 8 two weeks now and I love...  positive            1
# 4     I bought this for my grand daughter when she c...  positive            1
# ...                                                 ...       ...          ...
# 4995  This is a great tablet for the price. Amazon i...  positive            1
# 4996  This tablet is the perfect size and so easy to...  positive            1
# 4997  Purchased this for my son. Has room to upgrade...  positive            1
# 4998  I had some thoughts about getting this for a 5...  positive            1
# 4999  this is a steal, have 8 gb model as well.This ...  positive            1
#
# [49766 rows x 7 columns]

# %%
temp_data['reviews.doRecommend'].value_counts()
# Out:
# True     47067
# False     2145
# Name: reviews.doRecommend, dtype: int64

# %%
temp_data.drop(['DoRecommend'], axis = 'columns', inplace = True)

# %%
temp_data.head(3)
# Out:
#     brand reviews.doRecommend  reviews.numHelpful  reviews.rating  \
# 0  Amazon                True                 0.0             5.0
# 1  Amazon                True                 0.0             5.0
# 2  Amazon                True                 0.0             5.0
#
#                                         reviews.text sentiment
# 0  This product so far has not disappointed. My c...  positive
# 1  great for beginner or experienced person. Boug...  positive
# 2  Inexpensive tablet for him to use and learn on...  positive

# %%
temp_data1 = dataset.copy()

# %%
temp_data1.head(3)
# Out:
#     brand manufacturer reviews.doRecommend  reviews.numHelpful  \
# 0  Amazon       Amazon                True                 0.0
# 1  Amazon       Amazon                True                 0.0
# 2  Amazon       Amazon                True                 0.0
#
#    reviews.rating                                       reviews.text
# 0             5.0  This product so far has not disappointed. My c...
# 1             5.0  great for beginner or experienced person. Boug...
# 2             5.0  Inexpensive tablet for him to use and learn on...

# %%
temp_data1 = temp_data1[temp_data1['brand'] == temp_data1['manufacturer']]

# %%
temp_data1.shape
# Out:
# (49766, 6)

# %%
temp_data1 = temp_data1.drop(['manufacturer'] , axis = 'columns')

# %%
temp_data1.head(3)
# Out:
#     brand reviews.doRecommend  reviews.numHelpful  reviews.rating  \
# 0  Amazon                True                 0.0             5.0
# 1  Amazon                True                 0.0             5.0
# 2  Amazon                True                 0.0             5.0
#
#                                         reviews.text
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...

# %%
temp_data['sentiment'] = temp_data["reviews.rating"].apply(lambda score: 1 if score > 3 else \
                                              (0 if score < 3 else 2))

# %% [markdown]
# ##### Here, 1 for positive, 2 for Neutral and 0 for negative

# %%
pd.pandas.set_option('display.max_rows',None)

# %%
temp_data.groupby('sentiment').agg('count')
# Out:
#            brand  reviews.doRecommend  reviews.numHelpful  reviews.rating  \
# sentiment
# 0           1231                 1168                1191            1231
# 1          46329                45896               45922           46329
# 2           2206                 2148                2152            2174
#
#            reviews.text
# sentiment
# 0                  1231
# 1                 46328
# 2                  2206

# %%
temp_data.shape
# Out:
# (49766, 6)

# %%
temp_data.isnull().sum()
# Out:
# brand                    0
# reviews.doRecommend    554
# reviews.numHelpful     501
# reviews.rating          32
# reviews.text             1
# sentiment                0
# dtype: int64

# %%
temp_data = temp_data.dropna()

# %%
temp_data.isnull().sum()
# Out:
# brand                  0
# reviews.doRecommend    0
# reviews.numHelpful     0
# reviews.rating         0
# reviews.text           0
# sentiment              0
# dtype: int64

# %%
temp_data.shape
# Out:
# (49210, 6)

# %%
temp_data.groupby('sentiment').agg('count')
# Out:
#            brand  reviews.doRecommend  reviews.numHelpful  reviews.rating  \
# sentiment
# 0           1168                 1168                1168            1168
# 1          45894                45894               45894           45894
# 2           2148                 2148                2148            2148
#
#            reviews.text
# sentiment
# 0                  1168
# 1                 45894
# 2                  2148

# %%
temp_data.head(3)
# Out:
#     brand reviews.doRecommend  reviews.numHelpful  reviews.rating  \
# 0  Amazon                True                 0.0             5.0
# 1  Amazon                True                 0.0             5.0
# 2  Amazon                True                 0.0             5.0
#
#                                         reviews.text  sentiment
# 0  This product so far has not disappointed. My c...          1
# 1  great for beginner or experienced person. Boug...          1
# 2  Inexpensive tablet for him to use and learn on...          1

# %%
dummies1 = pd.get_dummies(temp_data['reviews.doRecommend'],prefix='doRecommend')

# %%
dummies1.head(10)
# Out:
#    doRecommend_False  doRecommend_True
# 0                  0                 1
# 1                  0                 1
# 2                  0                 1
# 3                  0                 1
# 4                  0                 1
# 5                  0                 1
# 6                  0                 1
# 7                  0                 1
# 8                  0                 1
# 9                  0                 1

# %%
temp_data.groupby('brand').agg('count')
# Out:
#         reviews.doRecommend  reviews.numHelpful  reviews.rating  reviews.text  \
# brand
# Amazon                49210               49210           49210         49210
#
#         sentiment
# brand
# Amazon      49210

# %%
temp_data = pd.concat([temp_data,dummies1.drop('doRecommend_False',axis='columns')],axis='columns')

# %%
temp_data.head()
# Out:
#     brand reviews.doRecommend  reviews.numHelpful  reviews.rating  \
# 0  Amazon                True                 0.0             5.0
# 1  Amazon                True                 0.0             5.0
# 2  Amazon                True                 0.0             5.0
# 3  Amazon                True                 0.0             4.0
# 4  Amazon                True                 0.0             5.0
#
#                                         reviews.text  sentiment  \
# 0  This product so far has not disappointed. My c...          1
# 1  great for beginner or experienced person. Boug...          1
# 2  Inexpensive tablet for him to use and learn on...          1
# 3  I've had my Fire HD 8 two weeks now and I love...          1
# 4  I bought this for my grand daughter when she c...          1
#
#    doRecommend_True
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
temp_data2 = temp_data.drop(['brand','reviews.doRecommend'], axis = 'columns')

# %%
temp_data2.head()
# Out:
#    reviews.numHelpful  reviews.rating  \
# 0                 0.0             5.0
# 1                 0.0             5.0
# 2                 0.0             5.0
# 3                 0.0             4.0
# 4                 0.0             5.0
#
#                                         reviews.text  sentiment  \
# 0  This product so far has not disappointed. My c...          1
# 1  great for beginner or experienced person. Boug...          1
# 2  Inexpensive tablet for him to use and learn on...          1
# 3  I've had my Fire HD 8 two weeks now and I love...          1
# 4  I bought this for my grand daughter when she c...          1
#
#    doRecommend_True
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %% [markdown]
# Now our task is to classify our dataset['reviews.text'] into positive, negative and neutral i.e 1,0,2 respectively

# %%
temp_data2_pos = temp_data2[temp_data2["sentiment"].isin([1])]
temp_data2_neg = temp_data2[temp_data2["sentiment"].isin([0])]
temp_data2_neutral = temp_data2[temp_data2["sentiment"].isin([2])]

# %%
temp_data2_pos.head()
# Out:
#    reviews.numHelpful  reviews.rating  \
# 0                 0.0             5.0
# 1                 0.0             5.0
# 2                 0.0             5.0
# 3                 0.0             4.0
# 4                 0.0             5.0
#
#                                         reviews.text  sentiment  \
# 0  This product so far has not disappointed. My c...          1
# 1  great for beginner or experienced person. Boug...          1
# 2  Inexpensive tablet for him to use and learn on...          1
# 3  I've had my Fire HD 8 two weeks now and I love...          1
# 4  I bought this for my grand daughter when she c...          1
#
#    doRecommend_True
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
temp_data2_neg.head()
# Out:
#      reviews.numHelpful  reviews.rating  \
# 117                 0.0             2.0
# 126                 2.0             1.0
# 169                 2.0             1.0
# 241                 0.0             1.0
# 281                 0.0             2.0
#
#                                           reviews.text  sentiment  \
# 117  Didn't have some of the features I was looking...          0
# 126  i Bought this around black friday for $60 hopi...          0
# 169  I bought this tablet for my 4 year old daughte...          0
# 241  Didn't want to go to the sites amazon wanted m...          0
# 281  Not a good product short battery life i can on...          0
#
#      doRecommend_True
# 117                 1
# 126                 0
# 169                 0
# 241                 0
# 281                 0

# %%
temp_data2_neutral.head()
# Out:
#      reviews.numHelpful  reviews.rating  \
# 222                 0.0             3.0
# 226                 0.0             3.0
# 298                 0.0             3.0
# 354                 0.0             3.0
# 371                 0.0             3.0
#
#                                           reviews.text  sentiment  \
# 222  I was hoping to use Google launcher with this ...          2
# 226  The tablet works fine. It is responsive with g...          2
# 298  Fine for reading, ...haven't used it for anyth...          2
# 354  Though I have got it for cheap price during bl...          2
# 371  This is a good product for video, surfing and ...          2
#
#      doRecommend_True
# 222                 0
# 226                 0
# 298                 1
# 354                 1
# 371                 1

# %%
temp_data_final = pd.concat([temp_data2_pos, temp_data2_neg, temp_data2_neutral])

# %%
temp_data_final.shape
# Out:
# (49210, 5)

# %%
temp_data2_neutral.shape
# Out:
# (2148, 5)

# %%
temp_data2_pos.shape
# Out:
# (45894, 5)

# %%
temp_data2_neg.shape
# Out:
# (1168, 5)

# %%
temp_data_final.head()
# Out:
#    reviews.numHelpful  reviews.rating  \
# 0                 0.0             5.0
# 1                 0.0             5.0
# 2                 0.0             5.0
# 3                 0.0             4.0
# 4                 0.0             5.0
#
#                                         reviews.text  sentiment  \
# 0  This product so far has not disappointed. My c...          1
# 1  great for beginner or experienced person. Boug...          1
# 2  Inexpensive tablet for him to use and learn on...          1
# 3  I've had my Fire HD 8 two weeks now and I love...          1
# 4  I bought this for my grand daughter when she c...          1
#
#    doRecommend_True
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
temp_data_final.tail()
# Out:
#       reviews.numHelpful  reviews.rating  \
# 4807                 0.0             3.0
# 4842                 0.0             3.0
# 4880                 0.0             3.0
# 4945                 0.0             3.0
# 4975                 0.0             3.0
#
#                                            reviews.text  sentiment  \
# 4807  meh. it works. i find it difficult to navigate...          2
# 4842  Decent little tablet if you are not a game pla...          2
# 4880  I bought this as a Christmas gift for my wife ...          2
# 4945  My daughter has had this tablet for almost 2 m...          2
# 4975  I wish it has some more of the apps from the p...          2
#
#       doRecommend_True
# 4807                 0
# 4842                 1
# 4880                 0
# 4945                 1
# 4975                 1

# %%
#temp_data_final.head(45900)

# %%
temp_data_final.sentiment.value_counts()
# Out:
# 1    45894
# 2     2148
# 0     1168
# Name: sentiment, dtype: int64

# %% [markdown]
# ### split the data into train/test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(temp_data_final['reviews.text'], temp_data_final['sentiment'], test_size = 0.2)

# %%
X_train.head()
# Out:
# 9531     Bought this for niece amd nephews. Was easy to...
# 14545    This tablet is well worth the money. It has de...
# 22258    This was a purchase for Christmas! Great table...
# 4057     This serves every function I need in a tablet....
# 4154     Good for kids ... brightness is not so good, ....
# Name: reviews.text, dtype: object

# %%
y_train.head()
# Out:
# 9531     1
# 14545    1
# 22258    1
# 4057     1
# 4154     2
# Name: sentiment, dtype: int64

# %% [markdown]
# ## CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vector=CountVectorizer(stop_words="english")

# %%
count_vector.fit(X_train)
# Out:
# CountVectorizer(stop_words='english')

# %%
X_train_new = count_vector.transform(X_train)

# %%
X_train_new.shape
# Out:
# (39368, 11841)

# %%
X_test_new = count_vector.transform(X_test)

# %%
from sklearn.svm import LinearSVC
model = LinearSVC()

# %%
model.fit(X_train_new,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# LinearSVC()

# %%
model.predict(X_test_new)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
model.score(X_test_new, y_test)
# Out:
# 0.9501117659012396

# %%
count_vector2 = CountVectorizer(stop_words="english")

# %%
X_train_new
# Out:
# <39368x11841 sparse matrix of type '<class 'numpy.int64'>'
# 	with 496900 stored elements in Compressed Sparse Row format>

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(y_test, model.predict(X_test_new))
cfm
# Out:
# array([[ 123,   85,   28],
#        [  31, 9045,   97],
#        [  16,  234,  183]], dtype=int64)

# %%
model.score(X_test_new, y_test)
# Out:
# 0.9501117659012396

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cfm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
X = count_vector.transform(temp_data_final['reviews.text'])
y = temp_data_final['sentiment']

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
cv = ShuffleSplit(n_splits =5, test_size=0.2, random_state=11)
cross_val_score(LinearSVC(),X,y,cv=cv)
# Out:
# array([0.95366795, 0.95143264, 0.95244869, 0.95285511, 0.95356635])

# %%
temp_data_final.head(3)
# Out:
#    reviews.numHelpful  reviews.rating  \
# 0                 0.0             5.0
# 1                 0.0             5.0
# 2                 0.0             5.0
#
#                                         reviews.text  sentiment  \
# 0  This product so far has not disappointed. My c...          1
# 1  great for beginner or experienced person. Boug...          1
# 2  Inexpensive tablet for him to use and learn on...          1
#
#    doRecommend_True
# 0                 1
# 1                 1
# 2                 1

# %%
data11 = temp_data_final.sample(frac=0.2)
print(len(data11))
data11.head()
# Out:
# 9842
#        reviews.numHelpful  reviews.rating  \
# 16477                 0.0             5.0
# 988                   0.0             5.0
# 9413                  0.0             5.0
# 21536                 0.0             5.0
# 18934                 0.0             4.0
#
#                                             reviews.text  sentiment  \
# 16477  great tablet for children, lots of content. ga...          1
# 988    Purchased as a gift. The receiver loves it and...          1
# 9413   We bought a Samsung washer and a drier. Produc...          1
# 21536  Paired this with a Bluetooth keyboard and now ...          1
# 18934  Perfect for what I need to use it for movies e...          1
#
#        doRecommend_True
# 16477                 1
# 988                   1
# 9413                  1
# 21536                 1
# 18934                 1

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Varadharajan
# [nltk_data]     Palani\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
from nltk import word_tokenize
from gensim.models import word2vec
target = data11['sentiment']
data_value = data11['reviews.text'].map(word_tokenize).values
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
total_vocabulary = set(word for headline in data_value for word in headline)
len(total_vocabulary)
print('There are {} unique tokens in the dataset.'.format(len(total_vocabulary)))
# Out:
# There are 10223 unique tokens in the dataset.

# %%
glove = {}
with open('C:\\Users\\Varadharajan Palani\\Downloads\\glove\\glove.6B.50d.txt', 'rb') as f:
    for line in f:
        parts = line.split()
        word = parts[0].decode('utf-8')
        if word in total_vocabulary:
            vector = np.array(parts[1:], dtype=np.float32)
            glove[word] = vector

# %%
glove['review']
# Out:
# array([-0.094903,  0.11984 , -0.73262 , -0.12816 , -0.45065 , -0.42703 ,
#        -0.31404 , -0.2888  ,  1.1209  , -0.14501 , -0.6902  ,  0.5469  ,
#        -0.27214 ,  0.3649  ,  0.54982 , -0.35273 , -0.12575 , -0.72552 ,
#         0.2356  , -0.094686,  0.9763  ,  0.27642 ,  0.39827 , -0.39296 ,
#        -0.21534 , -1.4118  , -0.53259 , -0.10365 , -1.0972  ,  0.069262,
#         2.8649  , -0.98303 , -0.56226 , -1.0736  , -0.12693 , -0.34976 ,
#         0.70635 , -0.38184 , -0.13337 , -0.75927 , -0.055391, -0.20889 ,
#         0.27749 ,  0.035698, -0.71724 ,  0.34967 ,  0.31645 ,  1.4766  ,
#        -0.083603,  0.89653 ], dtype=float32)

# %%
class W2vVectorizer(object):

    def __init__(self, w2v):
        # Takes in a dictionary of words and vectors as input
        self.w2v = w2v
        if len(w2v) == 0:
            self.dimensions = 0
        else:
            self.dimensions = len(w2v[next(iter(glove))])

    # Note: Even though it doesn't do anything, it's required that this object implement a fit method or else
    # it can't be used in a scikit-learn pipeline  
    def fit(self, X, y):
        return self

    def transform(self, X):
        return np.array([
            np.mean([self.w2v[w] for w in words if w in self.w2v]
                   or [np.zeros(self.dimensions)], axis=0) for words in X])

# %%
from sklearn.pipeline import Pipeline
linear_svc = Pipeline([('Word2Vec Vectorizer', W2vVectorizer(glove)),
                ('Support Vector Machine', LinearSVC())])

# %%
models = [('Support Vector Machine', linear_svc)]

# %%
scores = [(name, cross_val_score(model, data_value, target, cv=2).mean()) for name, model, in models]

# %%
scores
# Out:
# [('Support Vector Machine', 0.9333468807153018)]
