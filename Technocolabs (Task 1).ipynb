# %% [markdown]
# ## Loading Data and inspection

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\ved prakash shukla\\Technocolabs'

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
amazon = pd.read_csv('Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv',)
amazon.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 3  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 4  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# ...

# %%
amazon.columns
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'name', 'asins', 'brand',
#        'categories', 'primaryCategories', 'imageURLs', 'keys', 'manufacturer',
#        'manufacturerNumber', 'reviews.date', 'reviews.dateSeen',
#        'reviews.didPurchase', 'reviews.doRecommend', 'reviews.id',
#        'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.username', 'sourceURLs'],
#       dtype='object')

# %%
amazon.dtypes
# Out:
# id                      object
# dateAdded               object
# dateUpdated             object
# name                    object
# asins                   object
# brand                   object
# categories              object
# primaryCategories       object
# imageURLs               object
# keys                    object
# manufacturer            object
# manufacturerNumber      object
# reviews.date            object
# reviews.dateSeen        object
# reviews.didPurchase     object
# reviews.doRecommend     object
# reviews.id             float64
# reviews.numHelpful     float64
# reviews.rating           int64
# reviews.sourceURLs      object
# reviews.text            object
# reviews.title           object
# reviews.username        object
# sourceURLs              object
# dtype: object

# %%
amazon.drop_duplicates()
# Out:
#                          id             dateAdded           dateUpdated  \
# 0      AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1      AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2      AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 3      AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 4      AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# ...                     ...                   ...                   ...
# 28327  AVqkIhxunnc1JgDc3kg_  2017-03-06T14:59:43Z  2019-02-23T02:49:38Z
# 28328  AVqkIhxunnc1JgDc3kg_  2017-03-06T14:59:43Z  2019-02-23T02:49:38Z
# 28329  AVqkIhxunnc1JgDc3kg_  2017-03-06T14:59:43Z  2019-02-23T02:49:38Z
# 28330  AVqkIhxunnc1JgDc3kg_  2017-03-06T14:59:43Z  2019-02-23T02:49:38Z
# 28331  AVqkIhxunnc1JgDc3kg_  2017-03-06T14:59:43Z  2019-02-23T02:49:38Z
#
#                                                     name  \
# ...

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28332 entries, 0 to 28331
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   28332 non-null  object
#  1   dateAdded            28332 non-null  object
#  2   dateUpdated          28332 non-null  object
#  3   name                 28332 non-null  object
#  4   asins                28332 non-null  object
#  5   brand                28332 non-null  object
#  6   categories           28332 non-null  object
#  7   primaryCategories    28332 non-null  object
#  8   imageURLs            28332 non-null  object
#  9   keys                 28332 non-null  object
#  10  manufacturer         28332 non-null  object
#  11  manufacturerNumber   28332 non-null  object
#  12  reviews.date         28332 non-null  object
#  13  reviews.dateSeen     28332 non-null  object
#  14  reviews.didPurchase  9 non-null      object
# ...

# %%
amazon.isnull().sum()
# Out:
# id                         0
# dateAdded                  0
# dateUpdated                0
# name                       0
# asins                      0
# brand                      0
# categories                 0
# primaryCategories          0
# imageURLs                  0
# keys                       0
# manufacturer               0
# manufacturerNumber         0
# reviews.date               0
# reviews.dateSeen           0
# reviews.didPurchase    28323
# reviews.doRecommend    12246
# reviews.id             28291
# reviews.numHelpful     12217
# reviews.rating             0
# reviews.sourceURLs         0
# reviews.text               0
# reviews.title              0
# reviews.username           0
# sourceURLs                 0
# dtype: int64

# %%
amazon.shape
# Out:
# (28332, 24)

# %% [markdown]
# # Data Cleaning

# %%
# first we have to deal with the null values in columns
# first checking the % of the missing values
amazon = amazon.drop(['reviews.didPurchase'],axis = 1)
amazon = amazon.drop(['reviews.id'],axis = 1)

# dropping the columns since its almost all the values are null and it doesnot have any relevance to our analysis

# %%
# check the % of missing values of reviews.didpurchase column
(12246/28332)*100
# Out:
# 43.22321050402372

# %%
# dropping just all the null values
amazon = amazon[~amazon['reviews.doRecommend'].isnull()]
amazon = amazon[~amazon['reviews.numHelpful'].isnull()]

# %%
amazon.isnull().sum()
# Out:
# id                     0
# dateAdded              0
# dateUpdated            0
# name                   0
# asins                  0
# brand                  0
# categories             0
# primaryCategories      0
# imageURLs              0
# keys                   0
# manufacturer           0
# manufacturerNumber     0
# reviews.date           0
# reviews.dateSeen       0
# reviews.doRecommend    0
# reviews.numHelpful     0
# reviews.rating         0
# reviews.sourceURLs     0
# reviews.text           0
# reviews.title          0
# reviews.username       0
# sourceURLs             0
# dtype: int64

# %% [markdown]
# All the columns have no null values!!!

# %%
# changing the columns into appropiate datatype

# %%
amazon.dtypes
# Out:
# id                      object
# dateAdded               object
# dateUpdated             object
# name                    object
# asins                   object
# brand                   object
# categories              object
# primaryCategories       object
# imageURLs               object
# keys                    object
# manufacturer            object
# manufacturerNumber      object
# reviews.date            object
# reviews.dateSeen        object
# reviews.doRecommend     object
# reviews.numHelpful     float64
# reviews.rating           int64
# reviews.sourceURLs      object
# reviews.text            object
# reviews.title           object
# reviews.username        object
# sourceURLs              object
# dtype: object

# %%
# Date Time

amazon['dateAdded'] = pd.to_datetime(amazon['dateAdded'])
amazon['dateUpdated'] = pd.to_datetime(amazon['dateUpdated'])

# %%
# creating the new columns
amazon['dateAdded_years'] = amazon['dateAdded'].dt.year
amazon['dateAdded_month'] = amazon['dateAdded'].dt.month

# Now, dropping the columns
amazon = amazon.drop(['dateAdded'],axis = 1)

# %%
# creating the new columns
amazon['dateUpdated_years'] = amazon['dateUpdated'].dt.year
amazon['dateUpdated_month'] = amazon['dateUpdated'].dt.month

# Now, dropping the columns

amazon = amazon.drop(['dateUpdated'],axis = 1)

# %%
# changing the daTA TYpe
amazon['reviews.date_year'] = pd.to_datetime(amazon['reviews.date']).dt.year
amazon['reviews.date_month'] = pd.to_datetime(amazon['reviews.date']).dt.month

# %%
amazon = amazon.drop(['reviews.date'],axis = 1)

# %%
# dropping the columns
var = ['asins','keys','manufacturerNumber','id']
amazon = amazon.drop(var,axis =1)

# %%
amazon.head()
# Out:
#                                                     name   brand  \
# 8350                          Echo Spot Pair Kit (Black)  Amazon
# 8351                          Echo Spot Pair Kit (Black)  Amazon
# 12167  Amazon 9W PowerFast Official OEM USB Charger a...  Amazon
# 12168  Amazon 9W PowerFast Official OEM USB Charger a...  Amazon
# 12169  Amazon 9W PowerFast Official OEM USB Charger a...  Amazon
#
#                                               categories primaryCategories  \
# 8350   Amazon Echo,Networking,Home & Tools,Smart Home...       Electronics
# 8351   Amazon Echo,Networking,Home & Tools,Smart Home...       Electronics
# 12167  Computers & Accessories,Tablet & E-Reader Acce...       Electronics
# 12168  Computers & Accessories,Tablet & E-Reader Acce...       Electronics
# 12169  Computers & Accessories,Tablet & E-Reader Acce...       Electronics
#
#                                                imageURLs manufacturer  \
# ...

# %%
amazon['reviews.dateSeen'] = amazon['reviews.dateSeen'].astype('str')

# %%
amazon = amazon.drop(['imageURLs'],axis = 1)
amazon = amazon.drop(['sourceURLs'],axis = 1)

# %%
amazon.head()
# Out:
#                                                     name   brand  \
# 8350                          Echo Spot Pair Kit (Black)  Amazon
# 8351                          Echo Spot Pair Kit (Black)  Amazon
# 12167  Amazon 9W PowerFast Official OEM USB Charger a...  Amazon
# 12168  Amazon 9W PowerFast Official OEM USB Charger a...  Amazon
# 12169  Amazon 9W PowerFast Official OEM USB Charger a...  Amazon
#
#                                               categories primaryCategories  \
# 8350   Amazon Echo,Networking,Home & Tools,Smart Home...       Electronics
# 8351   Amazon Echo,Networking,Home & Tools,Smart Home...       Electronics
# 12167  Computers & Accessories,Tablet & E-Reader Acce...       Electronics
# 12168  Computers & Accessories,Tablet & E-Reader Acce...       Electronics
# 12169  Computers & Accessories,Tablet & E-Reader Acce...       Electronics
#
#       manufacturer                                   reviews.dateSeen  \
# ...

# %%
# visualisation
amazon['reviews.rating'].value_counts()
# Out:
# 5    10779
# 4     4230
# 3      659
# 2      212
# 1      206
# Name: reviews.rating, dtype: int64

# %%
amazon.columns
# Out:
# Index(['name', 'brand', 'categories', 'primaryCategories', 'manufacturer',
#        'reviews.dateSeen', 'reviews.doRecommend', 'reviews.numHelpful',
#        'reviews.rating', 'reviews.sourceURLs', 'reviews.text', 'reviews.title',
#        'reviews.username', 'dateAdded_years', 'dateAdded_month',
#        'dateUpdated_years', 'dateUpdated_month', 'reviews.date_year',
#        'reviews.date_month'],
#       dtype='object')

# %%
plt.figure(figsize=[6,12])
amazon.groupby(['reviews.rating'])['dateAdded_years'].sum().plot.bar()
plt.title('rating per years')
plt.xlabel('ratings'),plt.ylabel('years')
plt.show()

# %%
# line plot
plt.figure(figsize = [8,6])
plt.style.use('ggplot')
amazon.groupby(['dateAdded_month'])['reviews.rating'].mean().plot()
plt.title('trends over months of ratings',fontdict = {'fontsize' : 25,'fontweight':23,})
plt.ylabel('Ratings')
plt.legend('ratings')
plt.grid('True')

plt.show()

# %%
plt.figure(figsize = [7,7])
plt.style.use('fivethirtyeight')
plt.grid('True')
plt.hist(amazon['primaryCategories'],color = 'cyan',edgecolor ='black',align = 'left' )
plt.xticks(rotation = 90)
plt.title('frequency of Primary Categories', fontdict = {'fontsize':19,'fontweight':12 })
plt.show()

# %%
# bar
amazon.groupby(['primaryCategories'])['reviews.numHelpful'].mean().hist()
plt.xticks(rotation = 90)
plt.title('reviews helpful for Categories')
plt.show()

# %%
# scatter
plt.scatter(amazon['reviews.rating'],amazon['reviews.numHelpful'],s=50,c='r')

# %%
amazon.groupby(['reviews.doRecommend'])['reviews.rating'].sum().plot.bar()
plt.title('recommend reviews')
plt.style.use('ggplot')

# %% [markdown]
# ## dataset

# %%
# data set 
amazon_1 = pd.read_csv('Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv')
amazon_1.head(2)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# 0  Computers,Electronics Features,Tablets,Electro...       Electronics
# 1  Computers,Electronics Features,Tablets,Electro...       Electronics
#
#                                            imageURLs  \
# 0  https://pisces.bbystatic.com/image2/BestBuy_US...
# 1  https://pisces.bbystatic.com/image2/BestBuy_US...
#
#                                                 keys  ...  \
# 0  allnewkindleereaderblack6glarefreetouchscreend...  ...
# ...

# %%
amazon_1.shape
# Out:
# (5000, 24)

# %%
amazon_1.isnull().sum()
# Out:
# id                        0
# dateAdded                 0
# dateUpdated               0
# name                      0
# asins                     0
# brand                     0
# categories                0
# primaryCategories         0
# imageURLs                 0
# keys                      0
# manufacturer              0
# manufacturerNumber        0
# reviews.date              0
# reviews.dateAdded      3948
# reviews.dateSeen          0
# reviews.doRecommend       0
# reviews.id             4971
# reviews.numHelpful        0
# reviews.rating            0
# reviews.sourceURLs        0
# reviews.text              0
# reviews.title            13
# reviews.username          0
# sourceURLs                0
# dtype: int64

# %%
amazon_1.drop_duplicates().head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# ...

# %%
amazon_1.dtypes
# Out:
# id                      object
# dateAdded               object
# dateUpdated             object
# name                    object
# asins                   object
# brand                   object
# categories              object
# primaryCategories       object
# imageURLs               object
# keys                    object
# manufacturer            object
# manufacturerNumber      object
# reviews.date            object
# reviews.dateAdded       object
# reviews.dateSeen        object
# reviews.doRecommend       bool
# reviews.id             float64
# reviews.numHelpful       int64
# reviews.rating           int64
# reviews.sourceURLs      object
# reviews.text            object
# reviews.title           object
# reviews.username        object
# sourceURLs              object
# dtype: object

# %%
amazon_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   5000 non-null   object
#  1   dateAdded            5000 non-null   object
#  2   dateUpdated          5000 non-null   object
#  3   name                 5000 non-null   object
#  4   asins                5000 non-null   object
#  5   brand                5000 non-null   object
#  6   categories           5000 non-null   object
#  7   primaryCategories    5000 non-null   object
#  8   imageURLs            5000 non-null   object
#  9   keys                 5000 non-null   object
#  10  manufacturer         5000 non-null   object
#  11  manufacturerNumber   5000 non-null   object
#  12  reviews.date         5000 non-null   object
#  13  reviews.dateAdded    1052 non-null   object
#  14  reviews.dateSeen     5000 non-null   object
# ...

# %%
amazon_1.columns
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'name', 'asins', 'brand',
#        'categories', 'primaryCategories', 'imageURLs', 'keys', 'manufacturer',
#        'manufacturerNumber', 'reviews.date', 'reviews.dateAdded',
#        'reviews.dateSeen', 'reviews.doRecommend', 'reviews.id',
#        'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.username', 'sourceURLs'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %%
# dropping the columns since most of the values were null
amazon_1 = amazon_1.drop(["reviews.dateAdded",'reviews.id'],axis = 1)

# %%
# dropping the null values of "reviews.title" columns
amazon_1['reviews.title'] = amazon_1['reviews.title'].dropna(how = 'any',inplace = True)

# %%
# changing into apporpiate datatype
amazon_1['dateAdded_year'] = pd.to_datetime(amazon_1['dateAdded']).dt.year
amazon_1['dateAdded_month'] = pd.to_datetime(amazon_1['dateAdded']).dt.month
amazon_1['reviews.date_year'] = pd.to_datetime(amazon_1['reviews.date']).dt.year
amazon_1['reviews.date_month'] = pd.to_datetime(amazon_1['reviews.date']).dt.month

# dropping the columns
amazon_1 = amazon_1.drop(["dateAdded",'reviews.date'],axis = 1)

# %%
# data visualisation 
plt.figure(figsize=[6,12])
amazon_1.groupby(['reviews.rating'])['dateAdded_year'].sum().plot.bar()
plt.title('rating per years')
plt.xlabel('ratings'),plt.ylabel('years')
plt.show()

# %%
# line plot
plt.figure(figsize = [8,6])
plt.style.use('ggplot')
amazon_1.groupby(['dateAdded_month'])['reviews.rating'].mean().plot()
plt.title('trends over months of ratings',fontdict = {'fontsize' : 25,'fontweight':23,})
plt.ylabel('Ratings')
plt.legend('ratings')
plt.grid('True')

plt.show()

# %%
plt.figure(figsize = [7,7])
plt.style.use('fivethirtyeight')
plt.grid('True')
plt.hist(amazon_1['primaryCategories'],color = 'cyan',edgecolor ='black',align = 'left' )
plt.xticks(rotation = 90)
plt.title('frequency of Primary Categories', fontdict = {'fontsize':19,'fontweight':12 })
plt.show()

# %%
# bar
amazon_1.groupby(['primaryCategories'])['reviews.numHelpful'].mean().hist()
plt.xticks(rotation = 90)
plt.title('reviews helpful for Categories')
plt.show()

# %% [markdown]
# this is end of our data cleaning ,EDA and data visualisation and then we have to merge and perform a model for making prediction which depends on our "target variable"
